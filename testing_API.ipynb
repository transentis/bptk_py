# %%
import BPTK_Py.bptk as bptk
import BPTK_Py.config.config as config
import importlib
import matplotlib as plt
for key in config.matplotlib_rc_settings.keys():
    plt.rcParams[key] = config.matplotlib_rc_settings[key]

# %%
importlib.reload(bptk)
bptk.plotOutputsForScenario(scenario_name="MakeYouStartUpGrow", equations=['cash▸desiredMothsOfCoverage',"capabilities▸totalWorkforceExperience"],stacked=False, freq="D", start_date="1/11/2018",title="Multiple Equations for one Scenario\n",x_label="Time",y_label="Number")

# %%
bptk.plotScenarioForOutput(scenario_names=["MakeYouStartUpGrow_2","MakeYouStartUpGrow"],equation="cashFlow▸cashFlowYtd",stacked=False, freq="D", start_date="1/11/2018",title="One Equation for multiple Scenarios",x_label="Time",y_label="Number")
